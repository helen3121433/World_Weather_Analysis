# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations. size 2000
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# moratuwa lk
# taolanaro mg
# mataura pf
# ixtapa mx
# brae gb
# mataura pf
# touros br
# bur gabo so
# mora cm
# pisco pe
# komsomolskiy ru
# vitimskiy ru
# illoqqortoormiut gl
# matamba tz
# rikitea pf
# ichalkaranji in
# mys shmidta ru
# boa vista br
# chumikan ru
# souillac mu
# kapaa us
# mataura pf
# new norfolk au
# yanam in
# sompeta in
# boende cd
# huilong cn
# strezhevoy ru
# ushuaia ar
# tsihombe mg
# diffa ne
# albany au
# anuchino ru
# puerto leguizamo co
# daru pg
# yellowknife ca
# saint-philippe re
# tura ru
# deep river ca
# carnarvon au
# nikolskoye ru
# grand river south east mu
# albany au
# biltine td
# zvishavane zw
# severo-kurilsk ru
# qaanaaq gl
# olafsvik is
# belushya guba ru
# marcona pe
# rikitea pf
# lebu cl
# hamilton bm
# punta arenas cl
# mataura pf
# ushuaia ar
# vaini to
# necochea ar
# urucara br
# asfi ma
# mehamn no
# abu dhabi ae
# taolanaro mg
# hermanus za
# bredasdorp za
# iqaluit ca
# hermanus za
# odessa us
# buchanan lr
# atuona pf
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the API key.
from config import OpenWeather_API_KEY

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + OpenWeather_API_KEY
# print(url)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# try_url = city_url = url + "&q=" + "yellowknife"
# city_weather = requests.get(try_url)
# city_weather

# %%
# city_weather.json()

# %%
# yellowknife_data = city_weather.json()
# yellowknife_data["weather"]

# %%
# # receive error message when trying to run the list " list indices must be intergers or slices, not str"
# yellowknife_data["weather"]["description"]

# %%
# #try [0]
# yellowknife_data['weather'][0]['description']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | moratuwa
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | ixtapa
# Processing Record 5 of Set 1 | brae
# Processing Record 6 of Set 1 | touros
# Processing Record 7 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 1 | mora
# Processing Record 9 of Set 1 | pisco
# Processing Record 10 of Set 1 | komsomolskiy
# Processing Record 11 of Set 1 | vitimskiy
# City not found. Skipping...
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | matamba
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | ichalkaranji
# Processing Record 16 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 1 | boa vista
# Processing Record 18 of Set 1 | chumikan
# ...

# %%
len(city_data)
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Moratuwa      LK   6.7730   79.8816     80.62        75          89
# 1       Mataura      NZ -46.1927  168.8643     57.47        38          11
# 2        Ixtapa      MX  20.7000 -105.2000     72.63        73          20
# 3          Brae      GB  60.3964   -1.3530     39.11        54          90
# 4        Touros      BR  -5.1989  -35.4608     77.90        72          35
# 5          Mora      CM  11.0461   14.1401     60.55        22          11
# 6         Pisco      PE -13.7000  -76.2167     68.05        88           0
# 7  Komsomolskiy      UZ  40.4272   71.7189     38.12        32         100
# 8       Matamba      TZ  -8.9833   33.9667     55.56        86         100
# 9       Rikitea      PF -23.1203 -134.9692     79.36        69          91
#
#    Wind Speed Current Description                 Date
# 0        1.32     overcast clouds  2022-02-06 03:31:59
# ...

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
